# %% [markdown]
# # ~ 環境準備

# %%
# 掛載雲端硬碟 Mount google drive in CoLab enviroment
#from google.colab import drive
#drive.mount('gdrive')

# %%
# 匯入需要的 python 模組
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import layers, callbacks
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report, recall_score
from itertools import cycle, product
from scipy import interp

# %%
# 變更工作資料夾 --> 自己組別的資料夾 ex."/content/gdrive/Shareddrives/1112_AI智慧醫療三日工作坊/第01大組_"
my_working_root = "/Users/zhongyongting/1112/ai_workshop"
os.chdir(my_working_root)

# %% [markdown]
# # 1 資料處理
# |變項(中文)|變項(英文)|Coding|說明(中文)|說明(英文)|
# |---|---|---|---|---|
# |嗓音診斷分類(target)|Disease category|1/2/3/4/5|嗓音誤用/聲帶閉合不全/聲帶麻痺/聲帶腫瘤/聲帶正常|Phonotrauma/Incomplete glottic closure/Vocal palsy/Neoplasm/Normal|
# |性別|Sex|1/2|男性/女性|Male/Female
# |年齡|Age|numbers| |
# |音域變窄|Narrow pitch range|0/1|無/有|No/Yes
# |說話音量變小|Decreased volume|0/1|無/有|No/Yes
# |說話久了容易累|Fatigue|0/1|無/有|No/Yes
# |喉嚨常覺得乾|Dryness|0/1|無/有|No/Yes
# |喉嚨有異物感|Lumping|0/1|無/有|No/Yes
# |胸口有灼熱感|Heartburn|0/1|無/有|No/Yes
# |吞東西容易嗆到|Choking|0/1|無/有|No/Yes
# |眼睛乾澀|Eye dryness|0/1|無/有|No/Yes
# |鼻涕倒流|PND|0/1|無/有|No/Yes
# |糖尿病|Diabetes|0/1|無/有|No/Yes
# |高血壓|Hypertension|0/1|無/有|No/Yes
# |心臟病|CAD|0/1|無/有|No/Yes
# |頭頸部腫瘤|Head and Neck Cancer|0/1|無/有|No/Yes
# |頭部損傷|Head injury|0/1|無/有|No/Yes
# |腦中風|CVA|0/1|無/有|No/Yes
# |抽菸|Smoking|0/1/2/3|從未/已戒菸/有抽菸/電子菸|Never/past/active/e-cigarette
# |PPD|PPD|numbers|一天幾包菸|pack (of cigarrette) per day
# |喝酒|Drinking|0/1/2|從未喝酒/已戒酒/有喝酒|Never/past/active
# |喝酒頻率|Frequency|0/1/2/3|偶爾喝/每周喝/幾乎每天|Not/occasionally/ weekly/daily
# |症狀如何發生的|Onset of dysphonia|1/2/3/4/5|突然/逐漸變差/時好時壞/從小開始/其他|Sudden/Gradually/On and off/Since childhood/Other
# |工作環境是否吵雜|Noise at work|1/2/3|否/有一點/很吵|Not/a little/noisy
# |聲音何時最差|Diurnal pattern|1/2/3/4|早上/下午、晚上 /都一樣/不一定|Worse in the morning/Worse in the afternoon/Similar all day/Fluctuating
# |用聲情形|Occupational vocal demand|1/2/3/4|總是需要/經常需要/偶而需要/不需要|Always/Frequent/Occasional/Minimal
# |VHI-10嗓音障礙指標|Voice handicap index - 10|0 to 40| |

# %%
# 讀取資料表
df = pd.read_csv("/Users/zhongyongting/1112/ai_workshop/Data/Training Dataset/training datalist.csv")
df = df.loc[df['Sex'] == 1]

# %%
#資料表資料
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 1 to 999
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         378 non-null    object
#  1   Sex                        378 non-null    int64
#  2   Age                        378 non-null    int64
#  3   Disease category           378 non-null    int64
#  4   Narrow pitch range         378 non-null    int64
#  5   Decreased volume           378 non-null    int64
#  6   Fatigue                    378 non-null    int64
#  7   Dryness                    378 non-null    int64
#  8   Lumping                    378 non-null    int64
#  9   heartburn                  378 non-null    int64
#  10  Choking                    378 non-null    int64
#  11  Eye dryness                378 non-null    int64
#  12  PND                        378 non-null    int64
#  13  Smoking                    378 non-null    int64
#  14  PPD                        90 non-null     float64
#  15  Drinking                   378 non-null    int64
#  16  frequency                  378 non-null    int64
#  17  Diurnal pattern            378 non-null    int64
#  18  Onset of dysphonia         378 non-null    int64
#  19  Noise at work              378 non-null    int64
#  20  Occupational vocal demand  378 non-null    int64
#  21  Diabetes                   378 non-null    int64
#  22  Hypertension               378 non-null    int64
#  23  CAD                        378 non-null    int64
#  24  Head and Neck Cancer       378 non-null    int64
#  25  Head injury                378 non-null    int64
#  26  CVA                        378 non-null    int64
#  27  Voice handicap index - 10  374 non-null    float64
# dtypes: float64(2), int64(25), object(1)
# memory usage: 85.6+ KB

# %% [markdown]
# ## 1.0 標籤分析

# %%
# 分類標籤
CLASSES = ["Phonotrauma", "Incomplete glottic closure", "Vocal palsy", "Neoplasm", "Normal"]
df['Disease category'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Disease category'>

# %% [markdown]
# 下面block可優化

# %%
# 樣本權重 sample weight  (for imbalance data)
df['sample_weight'] = class_weight.compute_sample_weight('balanced', y=df['Disease category'])
df
# Out:
#           ID  Sex  Age  Disease category  Narrow pitch range  \
# 1    0600ve0    1   69                 2                   1
# 4    0402jvt    1   87                 1                   0
# 9    11019sl    1   51                 1                   1
# 14   0402svh    1   91                 4                   0
# 15   0T0018b    1   74                 3                   0
# ..       ...  ...  ...               ...                 ...
# 993  1201pl2    1   35                 1                   1
# 994  0T022un    1   52                 3                   1
# 995  0G00ftn    1   75                 3                   0
# 996  1201pkr    1   40                 4                   0
# 999  04027it    1   72                 2                   1
#
#      Decreased volume  Fatigue  Dryness  Lumping  heartburn  ...  \
# 1                   1        1        1        0          0  ...
# 4                   0        0        0        0          0  ...
# 9                   1        0        1        1          0  ...
# 14                  0        0        0        0          0  ...
# 15                  1        0        1        0          0  ...
# ..                ...      ...      ...      ...        ...  ...
# 993                 0        1        1        1          1  ...
# 994                 1        0        0        0          0  ...
# 995                 0        0        0        0          0  ...
# 996                 0        1        0        0          0  ...
# 999                 1        1        1        0          0  ...
#
#      Noise at work  Occupational vocal demand  Diabetes  Hypertension  CAD  \
# 1                1                          3         0             0    0
# 4                1                          4         0             1    0
# 9                3                          2         0             1    0
# 14               1                          4         0             0    0
# 15               1                          3         0             1    0
# ..             ...                        ...       ...           ...  ...
# 993              2                          1         0             0    0
# 994              1                          3         0             0    0
# 995              1                          4         1             1    1
# 996              1                          2         0             0    0
# 999              1                          3         0             0    0
#
#      Head and Neck Cancer  Head injury  CVA  Voice handicap index - 10  \
# 1                       0            0    1                       19.0
# 4                       0            0    0                       16.0
# 9                       0            0    0                       14.0
# 14                      0            0    0                        7.0
# 15                      0            0    0                       15.0
# ..                    ...          ...  ...                        ...
# 993                     0            0    0                       28.0
# 994                     0            0    0                       37.0
# 995                     0            0    0                       21.0
# 996                     0            0    0                       21.0
# 999                     0            0    0                       17.0
#
#      sample_weight
# 1         0.657391
# 4         0.547826
# 9         0.547826
# 14        2.290909
# 15        0.956962
# ..             ...
# 993       0.547826
# 994       0.956962
# 995       0.956962
# 996       2.290909
# 999       0.657391
#
# [378 rows x 29 columns]

# %%
# class weight (for imbalance data)
cw = class_weight.compute_class_weight('balanced', classes=np.array([1,2,3,4,5]), y=df['Disease category'])
class_weight_dict = dict(enumerate(cw))
print("CLASSES:", CLASSES)
print("class_weight_dict =", class_weight_dict)
# Out:
# CLASSES: ['Phonotrauma', 'Incomplete glottic closure', 'Vocal palsy', 'Neoplasm', 'Normal']
# class_weight_dict = {0: 0.5478260869565217, 1: 0.6573913043478261, 2: 0.9569620253164557, 3: 2.290909090909091, 4: 5.815384615384615}

# %% [markdown]
# ## 1.1 清理缺失值 (NA)

# %%
# PPD (一天幾包菸)
df['PPD'] = df['PPD'].fillna(0)  # 缺值補0
print("'PPD' na number =", df['PPD'].isna().sum())
# Out:
# 'PPD' na number = 0

# %%
df['Voice handicap index - 10'].plot(kind = 'bar', figsize = (200, 5))
# Out:
# <Axes: >

# %% [markdown]
# 下面Block可優化

# %%
# Voice handicap index - 10  (VHI-10嗓音障礙指標) 0-40
print(df['Voice handicap index - 10'].describe())
df.loc[df['Voice handicap index - 10'].isna(), 'Voice handicap index - 10'] = 23  # 缺值補23(中位數)
print("'Voice handicap index - 10' na number =", df['Voice handicap index - 10'].isna().sum())
# Out:
# count    374.000000
# mean      22.729947
# std        9.901624
# min        0.000000
# 25%       16.000000
# 50%       23.000000
# 75%       30.000000
# max       40.000000
# Name: Voice handicap index - 10, dtype: float64
# 'Voice handicap index - 10' na number = 0

# %%
df['Voice handicap index - 10'].plot(kind = 'bar', figsize = (200, 5))
# Out:
# <Axes: >

# %% [markdown]
# ## 1.2 處理 類別變項 (Categorical Feature) --> one-hot encoding
# 其他方法：https://axk51013.medium.com/%E4%B8%8D%E8%A6%81%E5%86%8D%E5%81%9Aone-hot-encoding-b5126d3f8a63

# %%
print("所有的欄位：", df.columns)
# Out:
# 所有的欄位： Index(['ID', 'Sex', 'Age', 'Disease category', 'Narrow pitch range',
#        'Decreased volume', 'Fatigue', 'Dryness', 'Lumping', 'heartburn',
#        'Choking', 'Eye dryness', 'PND', 'Smoking', 'PPD', 'Drinking',
#        'frequency', 'Diurnal pattern', 'Onset of dysphonia ', 'Noise at work',
#        'Occupational vocal demand', 'Diabetes', 'Hypertension', 'CAD',
#        'Head and Neck Cancer', 'Head injury', 'CVA',
#        'Voice handicap index - 10', 'sample_weight'],
#       dtype='object')

# %%
# 類別欄位 處理成one-hot (是非題的變因不處理)
categorical_columns = ['Sex', 'Smoking', 'Diurnal pattern', 'Onset of dysphonia ', 'Occupational vocal demand']
df_trans = pd.get_dummies(df, columns=categorical_columns)
df_trans
# Out:
#           ID  Age  Disease category  Narrow pitch range  Decreased volume  \
# 1    0600ve0   69                 2                   1                 1
# 4    0402jvt   87                 1                   0                 0
# 9    11019sl   51                 1                   1                 1
# 14   0402svh   91                 4                   0                 0
# 15   0T0018b   74                 3                   0                 1
# ..       ...  ...               ...                 ...               ...
# 993  1201pl2   35                 1                   1                 0
# 994  0T022un   52                 3                   1                 1
# 995  0G00ftn   75                 3                   0                 0
# 996  1201pkr   40                 4                   0                 0
# 999  04027it   72                 2                   1                 1
#
#      Fatigue  Dryness  Lumping  heartburn  Choking  ...  Diurnal pattern_4  \
# 1          1        1        0          0        1  ...                  0
# 4          0        0        0          0        0  ...                  1
# 9          0        1        1          0        0  ...                  1
# 14         0        0        0          0        0  ...                  0
# 15         0        1        0          0        0  ...                  0
# ..       ...      ...      ...        ...      ...  ...                ...
# 993        1        1        1          1        0  ...                  1
# 994        0        0        0          0        1  ...                  1
# 995        0        0        0          0        1  ...                  0
# 996        1        0        0          0        1  ...                  0
# 999        1        1        0          0        1  ...                  0
#
#      Onset of dysphonia _1  Onset of dysphonia _2  Onset of dysphonia _3  \
# 1                        0                      1                      0
# 4                        1                      0                      0
# 9                        0                      1                      0
# 14                       0                      1                      0
# 15                       1                      0                      0
# ..                     ...                    ...                    ...
# 993                      0                      1                      0
# 994                      0                      1                      0
# 995                      1                      0                      0
# 996                      0                      1                      0
# 999                      0                      1                      0
#
#      Onset of dysphonia _4  Onset of dysphonia _5  \
# 1                        0                      0
# 4                        0                      0
# 9                        0                      0
# 14                       0                      0
# 15                       0                      0
# ..                     ...                    ...
# 993                      0                      0
# 994                      0                      0
# 995                      0                      0
# 996                      0                      0
# 999                      0                      0
#
#      Occupational vocal demand_1  Occupational vocal demand_2  \
# 1                              0                            0
# 4                              0                            0
# 9                              0                            1
# 14                             0                            0
# 15                             0                            0
# ..                           ...                          ...
# 993                            1                            0
# 994                            0                            0
# 995                            0                            0
# 996                            0                            1
# 999                            0                            0
#
#      Occupational vocal demand_3  Occupational vocal demand_4
# 1                              1                            0
# 4                              0                            1
# 9                              0                            0
# 14                             0                            1
# 15                             1                            0
# ..                           ...                          ...
# 993                            0                            0
# 994                            1                            0
# 995                            0                            1
# 996                            0                            0
# 999                            1                            0
#
# [378 rows x 42 columns]

# %%
df_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 1 to 999
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           378 non-null    object
#  1   Age                          378 non-null    int64
#  2   Disease category             378 non-null    int64
#  3   Narrow pitch range           378 non-null    int64
#  4   Decreased volume             378 non-null    int64
#  5   Fatigue                      378 non-null    int64
#  6   Dryness                      378 non-null    int64
#  7   Lumping                      378 non-null    int64
#  8   heartburn                    378 non-null    int64
#  9   Choking                      378 non-null    int64
#  10  Eye dryness                  378 non-null    int64
#  11  PND                          378 non-null    int64
#  12  PPD                          378 non-null    float64
#  13  Drinking                     378 non-null    int64
#  14  frequency                    378 non-null    int64
#  15  Noise at work                378 non-null    int64
#  16  Diabetes                     378 non-null    int64
#  17  Hypertension                 378 non-null    int64
#  18  CAD                          378 non-null    int64
#  19  Head and Neck Cancer         378 non-null    int64
#  20  Head injury                  378 non-null    int64
#  21  CVA                          378 non-null    int64
#  22  Voice handicap index - 10    378 non-null    float64
#  23  sample_weight                378 non-null    float64
#  24  Sex_1                        378 non-null    uint8
#  25  Smoking_0                    378 non-null    uint8
#  26  Smoking_1                    378 non-null    uint8
#  27  Smoking_2                    378 non-null    uint8
#  28  Smoking_3                    378 non-null    uint8
#  29  Diurnal pattern_1            378 non-null    uint8
#  30  Diurnal pattern_2            378 non-null    uint8
#  31  Diurnal pattern_3            378 non-null    uint8
#  32  Diurnal pattern_4            378 non-null    uint8
#  33  Onset of dysphonia _1        378 non-null    uint8
#  34  Onset of dysphonia _2        378 non-null    uint8
#  35  Onset of dysphonia _3        378 non-null    uint8
#  36  Onset of dysphonia _4        378 non-null    uint8
#  37  Onset of dysphonia _5        378 non-null    uint8
#  38  Occupational vocal demand_1  378 non-null    uint8
#  39  Occupational vocal demand_2  378 non-null    uint8
#  40  Occupational vocal demand_3  378 non-null    uint8
#  41  Occupational vocal demand_4  378 non-null    uint8
# dtypes: float64(3), int64(20), object(1), uint8(18)
# memory usage: 80.5+ KB

# %% [markdown]
# ## 1.3 處理 連續變項 (Continuous Feature)

# %%
# 正規化(Normalization) [0.0 ~ 1.0]
df_trans['Age'] = df['Age'] / 100
df_trans['PPD'] = df['PPD'] / 2
df_trans['Drinking'] = df['Drinking'] / 2
df_trans['frequency'] = df['frequency'] / 3
df_trans['Noise at work'] = (df['Noise at work'] - 1) / 2
df_trans['Occupational vocal demand'] = (4 - df['Occupational vocal demand']) / 3
df_trans['Voice handicap index - 10'] = df['Voice handicap index - 10'] / 40
df_trans.describe()
# Out:
#               Age  Disease category  Narrow pitch range  Decreased volume  \
# count  378.000000        378.000000          378.000000        378.000000
# mean     0.519471          2.121693            0.402116          0.396825
# std      0.155934          1.105091            0.490975          0.489888
# min      0.200000          1.000000            0.000000          0.000000
# 25%      0.390000          1.000000            0.000000          0.000000
# 50%      0.530000          2.000000            0.000000          0.000000
# 75%      0.637500          3.000000            1.000000          1.000000
# max      0.970000          5.000000            1.000000          1.000000
#
#           Fatigue     Dryness     Lumping   heartburn     Choking  \
# count  378.000000  378.000000  378.000000  378.000000  378.000000
# mean     0.423280    0.436508    0.351852    0.063492    0.195767
# std      0.494734    0.496610    0.478181    0.244169    0.397316
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Eye dryness  ...  Onset of dysphonia _1  Onset of dysphonia _2  \
# count   378.000000  ...             378.000000             378.000000
# mean      0.145503  ...               0.275132               0.396825
# std       0.353074  ...               0.447173               0.489888
# min       0.000000  ...               0.000000               0.000000
# 25%       0.000000  ...               0.000000               0.000000
# 50%       0.000000  ...               0.000000               0.000000
# 75%       0.000000  ...               1.000000               1.000000
# max       1.000000  ...               1.000000               1.000000
#
#        Onset of dysphonia _3  Onset of dysphonia _4  Onset of dysphonia _5  \
# count             378.000000             378.000000             378.000000
# mean                0.179894               0.055556               0.092593
# std                 0.384608               0.229365               0.290245
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 0.000000               0.000000               0.000000
# max                 1.000000               1.000000               1.000000
#
#        Occupational vocal demand_1  Occupational vocal demand_2  \
# count                   378.000000                   378.000000
# mean                      0.349206                     0.280423
# std                       0.477351                     0.449801
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       1.000000                     1.000000
# max                       1.000000                     1.000000
#
#        Occupational vocal demand_3  Occupational vocal demand_4  \
# count                   378.000000                   378.000000
# mean                      0.264550                     0.105820
# std                       0.441678                     0.308015
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       1.000000                     0.000000
# max                       1.000000                     1.000000
#
#        Occupational vocal demand
# count                 378.000000
# mean                    0.624339
# std                     0.337247
# min                     0.000000
# 25%                     0.333333
# 50%                     0.666667
# 75%                     1.000000
# max                     1.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ## 1.4 處理 目標欄位 (target)

# %%
df_trans = pd.get_dummies(df_trans, columns=['Disease category'])
df_trans
# Out:
#           ID   Age  Narrow pitch range  Decreased volume  Fatigue  Dryness  \
# 1    0600ve0  0.69                   1                 1        1        1
# 4    0402jvt  0.87                   0                 0        0        0
# 9    11019sl  0.51                   1                 1        0        1
# 14   0402svh  0.91                   0                 0        0        0
# 15   0T0018b  0.74                   0                 1        0        1
# ..       ...   ...                 ...               ...      ...      ...
# 993  1201pl2  0.35                   1                 0        1        1
# 994  0T022un  0.52                   1                 1        0        0
# 995  0G00ftn  0.75                   0                 0        0        0
# 996  1201pkr  0.40                   0                 0        1        0
# 999  04027it  0.72                   1                 1        1        1
#
#      Lumping  heartburn  Choking  Eye dryness  ...  \
# 1          0          0        1            0  ...
# 4          0          0        0            0  ...
# 9          1          0        0            0  ...
# 14         0          0        0            1  ...
# 15         0          0        0            1  ...
# ..       ...        ...      ...          ...  ...
# 993        1          1        0            0  ...
# 994        0          0        1            1  ...
# 995        0          0        1            0  ...
# 996        0          0        1            0  ...
# 999        0          0        1            1  ...
#
#      Occupational vocal demand_1  Occupational vocal demand_2  \
# 1                              0                            0
# 4                              0                            0
# 9                              0                            1
# 14                             0                            0
# 15                             0                            0
# ..                           ...                          ...
# 993                            1                            0
# 994                            0                            0
# 995                            0                            0
# 996                            0                            1
# 999                            0                            0
#
#      Occupational vocal demand_3  Occupational vocal demand_4  \
# 1                              1                            0
# 4                              0                            1
# 9                              0                            0
# 14                             0                            1
# 15                             1                            0
# ..                           ...                          ...
# 993                            0                            0
# 994                            1                            0
# 995                            0                            1
# 996                            0                            0
# 999                            1                            0
#
#      Occupational vocal demand  Disease category_1  Disease category_2  \
# 1                     0.333333                   0                   1
# 4                     0.000000                   1                   0
# 9                     0.666667                   1                   0
# 14                    0.000000                   0                   0
# 15                    0.333333                   0                   0
# ..                         ...                 ...                 ...
# 993                   1.000000                   1                   0
# 994                   0.333333                   0                   0
# 995                   0.000000                   0                   0
# 996                   0.666667                   0                   0
# 999                   0.333333                   0                   1
#
#      Disease category_3  Disease category_4  Disease category_5
# 1                     0                   0                   0
# 4                     0                   0                   0
# 9                     0                   0                   0
# 14                    0                   1                   0
# 15                    1                   0                   0
# ..                  ...                 ...                 ...
# 993                   0                   0                   0
# 994                   1                   0                   0
# 995                   1                   0                   0
# 996                   0                   1                   0
# 999                   0                   0                   0
#
# [378 rows x 47 columns]

# %%
df_trans.columns
# Out:
# Index(['ID', 'Age', 'Narrow pitch range', 'Decreased volume', 'Fatigue',
#        'Dryness', 'Lumping', 'heartburn', 'Choking', 'Eye dryness', 'PND',
#        'PPD', 'Drinking', 'frequency', 'Noise at work', 'Diabetes',
#        'Hypertension', 'CAD', 'Head and Neck Cancer', 'Head injury', 'CVA',
#        'Voice handicap index - 10', 'sample_weight', 'Sex_1', 'Smoking_0',
#        'Smoking_1', 'Smoking_2', 'Smoking_3', 'Diurnal pattern_1',
#        'Diurnal pattern_2', 'Diurnal pattern_3', 'Diurnal pattern_4',
#        'Onset of dysphonia _1', 'Onset of dysphonia _2',
#        'Onset of dysphonia _3', 'Onset of dysphonia _4',
#        'Onset of dysphonia _5', 'Occupational vocal demand_1',
#        'Occupational vocal demand_2', 'Occupational vocal demand_3',
#        'Occupational vocal demand_4', 'Occupational vocal demand',
#        'Disease category_1', 'Disease category_2', 'Disease category_3',
#        'Disease category_4', 'Disease category_5'],
#       dtype='object')

# %%
# 特徵欄位 ('ID'不是特徵)
feature_columns = ['Age', 'Narrow pitch range', 'Decreased volume', 'Fatigue',
       'Dryness', 'Lumping', 'heartburn', 'Choking', 'Eye dryness', 'PND',
       'PPD', 'Drinking', 'frequency', 'Noise at work', 'Diabetes',
       'Hypertension', 'CAD', 'Head and Neck Cancer', 'Head injury', 'CVA',
       'Voice handicap index - 10', 'Sex_1', 'Smoking_0', 'Smoking_1',
       'Smoking_2', 'Smoking_3', 'Diurnal pattern_1', 'Diurnal pattern_2',
       'Diurnal pattern_3', 'Diurnal pattern_4', 'Onset of dysphonia _1',
       'Onset of dysphonia _2', 'Onset of dysphonia _3',
       'Onset of dysphonia _4', 'Onset of dysphonia _5',
       'Occupational vocal demand_1', 'Occupational vocal demand_2',
       'Occupational vocal demand_3', 'Occupational vocal demand_4',
       'Occupational vocal demand']
# 分類目標欄位
target_columns = ['Disease category_1', 'Disease category_2', 'Disease category_3', 'Disease category_4', 'Disease category_5']

print("特徵欄位數量 =", len(feature_columns))
print("目標欄位數量 =", len(target_columns))
# Out:
# 特徵欄位數量 = 40
# 目標欄位數量 = 5

# %% [markdown]
# ## 1.5 資料及分割 (train/valid)
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# 按診斷分類 切分 train/valid
train_index, valid_index = train_test_split(df_trans.index, train_size=0.8, random_state=333, stratify=df['Disease category'])
print('train_index shape =', train_index.shape)
print('valid_index shape =', valid_index.shape)
# Out:
# train_index shape = (302,)
# valid_index shape = (76,)

# %% [markdown]
# ## 1.6 樣本產生器(generator)
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset

# %%
# define tensorflow function
def train_preprocessing(idx):
    def py_preproc(idx):  # input tensor
        idx = idx.numpy()
        feats = df_trans.loc[idx, feature_columns].values
        label = df_trans.loc[idx, target_columns].values
        sample_weight = df_trans.loc[idx, 'sample_weight']       
        return feats, label, sample_weight

    feats, label, sample_weight = tf.py_function(func=py_preproc, inp=[idx], Tout=[tf.float32, tf.float32, tf.float32])
    return feats, label, sample_weight  # tensor output

def valid_preprocessing(idx):  # same as train_preprocessing but without augmentation and sample_weight
    def py_preproc(idx):  # input tensor
        idx = idx.numpy()
        feats = df_trans.loc[idx, feature_columns].values
        label = df_trans.loc[idx, target_columns].values
        return feats, label
        
    feats, label = tf.py_function(func=py_preproc, inp=[idx], Tout=[tf.float32, tf.float32])
    return feats, label  # tensor output

# tf function test:
idx = np.random.choice(df.index, size=1)[0]  # 隨機選一個資料索引
X, y, sw = train_preprocessing(idx)
print(f"X shape={X.shape} dtype={X.dtype.name}")
print("y =", y)
print("sample_weight =", sw)
# Out:
# X shape=(40,) dtype=float32
# y = tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32)
# sample_weight = tf.Tensor(0.6573913, shape=(), dtype=float32)

# %%
# prepare dataset as generator
batch_size = 64
autotune = tf.data.experimental.AUTOTUNE

train_generator = tf.data.Dataset.from_tensor_slices(train_index)  # train index
train_generator = train_generator.shuffle(len(train_index), reshuffle_each_iteration=True) \
                                .map(train_preprocessing, num_parallel_calls=4) \
                                .batch(batch_size) \
                                .prefetch(2)

valid_generator = tf.data.Dataset.from_tensor_slices(valid_index)  # valid index
valid_generator = valid_generator.map(valid_preprocessing, num_parallel_calls=4) \
                                .batch(batch_size) \
                                .prefetch(2)

# train_generator test:
for batch_x, batch_y, batch_sw in train_generator:
    print("batch_x shape:", batch_x.shape)
    print("batch_y shape:", batch_y.shape)
    print("batch_sw shape:", batch_sw.shape)
    break
# Out:
# batch_x shape: (64, 40)
# batch_y shape: (64, 5)
# batch_sw shape: (64,)
# 2023-05-13 16:26:01.300866: I tensorflow/core/common_runtime/executor.cc:1210] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [302]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-13 16:26:01.301022: I tensorflow/core/common_runtime/executor.cc:1210] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [302]
# 	 [[{{node Placeholder/_0}}]]

# %% [markdown]
# # 2 模型 Model

# %%
def build_model(feature_num, num_classes=5):
    inputs = layers.Input(shape=(feature_num, ), name="feats_sex1")

    # MLP
    x = layers.Dense(64, activation="relu", name="dense_sex1")(inputs)
    x = layers.Dense(64, activation="relu", name = 'dense_1_sex1')(x)
    x = layers.Dropout(0.1, name = 'dropout_sex1')(x)
    
    logits = layers.Dense(num_classes, name="logits_sex1")(x)

    model = Model(inputs=inputs, outputs=logits, name=f"feat{feature_num}_Unisex_Sex1")  # <-- 為模型命名(存檔資料夾名稱)
    return model

# Build model.
K.clear_session()
model = build_model(feature_num=len(feature_columns))
model.summary(line_length=160)
# Out:
# Model: "feat40_Unisex_Sex1"
# ________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                           Output Shape                                                    Param #
# ================================================================================================================================================================
#  feats_sex1 (InputLayer)                                                [(None, 40)]                                                    0
#
#  dense_sex1 (Dense)                                                     (None, 64)                                                      2624
#
#  dense_1_sex1 (Dense)                                                   (None, 64)                                                      4160
#
#  dropout_sex1 (Dropout)                                                 (None, 64)                                                      0
#
#  logits_sex1 (Dense)                                                    (None, 5)                                                       325
#
# ================================================================================================================================================================
# Total params: 7109 (27.77 KB)
# Trainable params: 7109 (27.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# ________________________________________________________________________________________________________________________________________________________________

# %%
# 看看設計架構
plot_model(model, to_file="/tmp/model.png", show_shapes=True, show_dtype=True, show_layer_names=True, dpi=48)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
def f1(y_true, y_pred):    
    def recall_m(y_true, y_pred):
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = TP / (Positives+K.epsilon())    
        return recall 
    def precision_m(y_true, y_pred):
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = TP / (Pred_Positives+K.epsilon())
        return precision 
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# Compile model
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              metrics=[tf.keras.metrics.AUC(name='auc'), 
                       f1, 
                       ])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# # 3 訓練 Training

# %%
# 建立模型儲存資料夾
model_dir = f"{my_working_root}/model/{model.name}"  # <-- 指定模型儲存的資料夾
os.makedirs(model_dir, exist_ok=True)

# Define callbacks
mc = callbacks.ModelCheckpoint(filepath= model_dir + '/best_model.h5', 
                               monitor='val_f1', mode='max', save_best_only=True)
rl = callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.5, patience=15)
es = callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=30)

# 開始訓練
EPOCHS = 300
history = model.fit(train_generator, 
                    epochs=EPOCHS, 
                    validation_data=valid_generator, 
                    callbacks=[mc, rl, es], 
                    )
# Out:
# Epoch 1/300
# 3/5 [=================>............] - ETA: 0s - loss: 1.5931 - auc: 0.4763 - f1: 0.0384
# 2023-05-13 16:26:02.210870: I tensorflow/core/common_runtime/executor.cc:1210] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [76]
# 	 [[{{node Placeholder/_0}}]]
# 5/5 [==============================] - 1s 88ms/step - loss: 1.6730 - auc: 0.5054 - f1: 0.0291 - val_loss: 1.5539 - val_auc: 0.5993 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 2/300
# 5/5 [==============================] - ETA: 0s - loss: 1.6038 - auc: 0.6022 - f1: 0.0263
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6038 - auc: 0.6022 - f1: 0.0263 - val_loss: 1.5310 - val_auc: 0.6628 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 3/300
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5801 - auc: 0.6357 - f1: 0.0504 - val_loss: 1.5257 - val_auc: 0.6715 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 4/300
# 5/5 [==============================] - 0s 40ms/step - loss: 1.5262 - auc: 0.6664 - f1: 0.0836 - val_loss: 1.5257 - val_auc: 0.6501 - val_f1: 0.0152 - lr: 0.0010
# Epoch 5/300
# 3/5 [=================>............] - ETA: 0s - loss: 1.3875 - auc: 0.6696 - f1: 0.1597
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 40ms/step - loss: 1.4873 - auc: 0.6950 - f1: 0.1522 - val_loss: 1.5034 - val_auc: 0.6707 - val_f1: 0.0152 - lr: 0.0010
# Epoch 6/300
# 5/5 [==============================] - 0s 41ms/step - loss: 1.4709 - auc: 0.7144 - f1: 0.1872 - val_loss: 1.4922 - val_auc: 0.6791 - val_f1: 0.0290 - lr: 0.0010
# Epoch 7/300
# 5/5 [==============================] - ETA: 0s - loss: 1.4070 - auc: 0.7479 - f1: 0.2512
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 41ms/step - loss: 1.4070 - auc: 0.7479 - f1: 0.2512 - val_loss: 1.4794 - val_auc: 0.6750 - val_f1: 0.0694 - lr: 0.0010
# Epoch 8/300
# 3/5 [=================>............] - ETA: 0s - loss: 1.4389 - auc: 0.7749 - f1: 0.3065
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3714 - auc: 0.7609 - f1: 0.3204 - val_loss: 1.4590 - val_auc: 0.6876 - val_f1: 0.1282 - lr: 0.0010
# Epoch 9/300
# 3/5 [=================>............] - ETA: 0s - loss: 1.4021 - auc: 0.7589 - f1: 0.3357
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3434 - auc: 0.7675 - f1: 0.3930 - val_loss: 1.4370 - val_auc: 0.6999 - val_f1: 0.1494 - lr: 0.0010
# Epoch 10/300
# 5/5 [==============================] - ETA: 0s - loss: 1.3080 - auc: 0.7911 - f1: 0.4709
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3080 - auc: 0.7911 - f1: 0.4709 - val_loss: 1.4126 - val_auc: 0.7035 - val_f1: 0.2172 - lr: 0.0010
# Epoch 11/300
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2696 - auc: 0.7932 - f1: 0.4756 - val_loss: 1.4080 - val_auc: 0.6968 - val_f1: 0.2156 - lr: 0.0010
# Epoch 12/300
# 5/5 [==============================] - 0s 43ms/step - loss: 1.2368 - auc: 0.7974 - f1: 0.5245 - val_loss: 1.3955 - val_auc: 0.7043 - val_f1: 0.2682 - lr: 0.0010
# Epoch 13/300
# 5/5 [==============================] - ETA: 0s - loss: 1.2141 - auc: 0.7957 - f1: 0.5161
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 43ms/step - loss: 1.2141 - auc: 0.7957 - f1: 0.5161 - val_loss: 1.3859 - val_auc: 0.7123 - val_f1: 0.3168 - lr: 0.0010
# Epoch 14/300
# 5/5 [==============================] - ETA: 0s - loss: 1.1535 - auc: 0.8132 - f1: 0.5763
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1535 - auc: 0.8132 - f1: 0.5763 - val_loss: 1.3650 - val_auc: 0.7134 - val_f1: 0.3754 - lr: 0.0010
# Epoch 15/300
# 3/5 [=================>............] - ETA: 0s - loss: 1.0808 - auc: 0.8053 - f1: 0.5461
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1196 - auc: 0.8188 - f1: 0.5687 - val_loss: 1.3485 - val_auc: 0.7179 - val_f1: 0.4174 - lr: 0.0010
# Epoch 16/300
# 5/5 [==============================] - ETA: 0s - loss: 1.0831 - auc: 0.8171 - f1: 0.5896
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0831 - auc: 0.8171 - f1: 0.5896 - val_loss: 1.3378 - val_auc: 0.7195 - val_f1: 0.4500 - lr: 0.0010
# Epoch 17/300
# 3/5 [=================>............] - ETA: 0s - loss: 1.0605 - auc: 0.8418 - f1: 0.5991
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0559 - auc: 0.8277 - f1: 0.5808 - val_loss: 1.3407 - val_auc: 0.7188 - val_f1: 0.4298 - lr: 0.0010
# Epoch 18/300
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0197 - auc: 0.8189 - f1: 0.5739 - val_loss: 1.3397 - val_auc: 0.7175 - val_f1: 0.4692 - lr: 0.0010
# Epoch 19/300
# 5/5 [==============================] - ETA: 0s - loss: 0.9874 - auc: 0.8141 - f1: 0.5685
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 44ms/step - loss: 0.9874 - auc: 0.8141 - f1: 0.5685 - val_loss: 1.3282 - val_auc: 0.7211 - val_f1: 0.4662 - lr: 0.0010
# Epoch 20/300
# 5/5 [==============================] - 0s 44ms/step - loss: 0.9698 - auc: 0.8285 - f1: 0.5892 - val_loss: 1.3084 - val_auc: 0.7320 - val_f1: 0.4556 - lr: 0.0010
# Epoch 21/300
# 5/5 [==============================] - 0s 44ms/step - loss: 0.9576 - auc: 0.8328 - f1: 0.6007 - val_loss: 1.2967 - val_auc: 0.7424 - val_f1: 0.5023 - lr: 0.0010
# Epoch 22/300
# 5/5 [==============================] - ETA: 0s - loss: 0.9023 - auc: 0.8433 - f1: 0.6079
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 43ms/step - loss: 0.9023 - auc: 0.8433 - f1: 0.6079 - val_loss: 1.2973 - val_auc: 0.7398 - val_f1: 0.5260 - lr: 0.0010
# Epoch 23/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.8973 - auc: 0.8452 - f1: 0.6126
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 40ms/step - loss: 0.8885 - auc: 0.8465 - f1: 0.6047 - val_loss: 1.3041 - val_auc: 0.7397 - val_f1: 0.5115 - lr: 0.0010
# Epoch 24/300
# 5/5 [==============================] - 0s 39ms/step - loss: 0.8532 - auc: 0.8458 - f1: 0.6049 - val_loss: 1.3195 - val_auc: 0.7346 - val_f1: 0.5104 - lr: 0.0010
# Epoch 25/300
# 5/5 [==============================] - 0s 37ms/step - loss: 0.8538 - auc: 0.8367 - f1: 0.5754 - val_loss: 1.3089 - val_auc: 0.7379 - val_f1: 0.4984 - lr: 0.0010
# Epoch 26/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8334 - auc: 0.8419 - f1: 0.6061 - val_loss: 1.3105 - val_auc: 0.7337 - val_f1: 0.5300 - lr: 0.0010
# Epoch 27/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.7974 - auc: 0.8485 - f1: 0.6150
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 41ms/step - loss: 0.8071 - auc: 0.8405 - f1: 0.5909 - val_loss: 1.3028 - val_auc: 0.7346 - val_f1: 0.5347 - lr: 0.0010
# Epoch 28/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.7661 - auc: 0.8421 - f1: 0.5838
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 42ms/step - loss: 0.7841 - auc: 0.8494 - f1: 0.5944 - val_loss: 1.2831 - val_auc: 0.7439 - val_f1: 0.5406 - lr: 0.0010
# Epoch 29/300
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7820 - auc: 0.8506 - f1: 0.5907 - val_loss: 1.2863 - val_auc: 0.7452 - val_f1: 0.5373 - lr: 0.0010
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 30/300
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7437 - auc: 0.8533 - f1: 0.6050 - val_loss: 1.3151 - val_auc: 0.7328 - val_f1: 0.5419 - lr: 0.0010
# Epoch 31/300
# 5/5 [==============================] - ETA: 0s - loss: 0.7279 - auc: 0.8595 - f1: 0.6084
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7279 - auc: 0.8595 - f1: 0.6084 - val_loss: 1.3084 - val_auc: 0.7341 - val_f1: 0.5464 - lr: 0.0010
# Epoch 32/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.7656 - auc: 0.8427 - f1: 0.6152
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7355 - auc: 0.8538 - f1: 0.6226 - val_loss: 1.2908 - val_auc: 0.7456 - val_f1: 0.5553 - lr: 0.0010
# Epoch 33/300
# 5/5 [==============================] - ETA: 0s - loss: 0.7116 - auc: 0.8602 - f1: 0.6180
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7116 - auc: 0.8602 - f1: 0.6180 - val_loss: 1.2826 - val_auc: 0.7443 - val_f1: 0.5458 - lr: 0.0010
# Epoch 34/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6852 - auc: 0.8701 - f1: 0.6262 - val_loss: 1.2854 - val_auc: 0.7460 - val_f1: 0.5473 - lr: 0.0010
# Epoch 35/300
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6777 - auc: 0.8643 - f1: 0.6300 - val_loss: 1.2958 - val_auc: 0.7409 - val_f1: 0.5398 - lr: 0.0010
# Epoch 36/300
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6319 - auc: 0.8791 - f1: 0.6337 - val_loss: 1.3135 - val_auc: 0.7362 - val_f1: 0.5412 - lr: 0.0010
# Epoch 37/300
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6628 - auc: 0.8654 - f1: 0.6233 - val_loss: 1.3217 - val_auc: 0.7337 - val_f1: 0.5460 - lr: 0.0010
# Epoch 38/300
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6411 - auc: 0.8740 - f1: 0.6229 - val_loss: 1.3183 - val_auc: 0.7385 - val_f1: 0.5446 - lr: 0.0010
# Epoch 39/300
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6508 - auc: 0.8654 - f1: 0.6314 - val_loss: 1.3131 - val_auc: 0.7438 - val_f1: 0.5215 - lr: 0.0010
# Epoch 40/300
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6111 - auc: 0.8785 - f1: 0.6382 - val_loss: 1.3077 - val_auc: 0.7429 - val_f1: 0.5242 - lr: 0.0010
# Epoch 41/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5934 - auc: 0.8827 - f1: 0.6388 - val_loss: 1.3203 - val_auc: 0.7407 - val_f1: 0.5228 - lr: 0.0010
# Epoch 42/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5962 - auc: 0.8766 - f1: 0.6376 - val_loss: 1.3335 - val_auc: 0.7379 - val_f1: 0.5130 - lr: 0.0010
# Epoch 43/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5921 - auc: 0.8757 - f1: 0.6323 - val_loss: 1.3353 - val_auc: 0.7418 - val_f1: 0.5023 - lr: 0.0010
# Epoch 44/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5617 - auc: 0.8813 - f1: 0.6449 - val_loss: 1.3279 - val_auc: 0.7405 - val_f1: 0.5023 - lr: 0.0010
# Epoch 45/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5598 - auc: 0.8854 - f1: 0.6429 - val_loss: 1.3253 - val_auc: 0.7460 - val_f1: 0.5010 - lr: 0.0010
# Epoch 46/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5366 - auc: 0.8832 - f1: 0.6405 - val_loss: 1.3471 - val_auc: 0.7384 - val_f1: 0.5025 - lr: 0.0010
# Epoch 47/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5178 - auc: 0.8847 - f1: 0.6239 - val_loss: 1.3511 - val_auc: 0.7436 - val_f1: 0.5013 - lr: 0.0010
# Epoch 48/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5151 - auc: 0.8909 - f1: 0.6432 - val_loss: 1.3418 - val_auc: 0.7511 - val_f1: 0.5017 - lr: 0.0010
# Epoch 49/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5172 - auc: 0.8950 - f1: 0.6575 - val_loss: 1.3468 - val_auc: 0.7526 - val_f1: 0.5017 - lr: 5.0000e-04
# Epoch 50/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4949 - auc: 0.8908 - f1: 0.6463 - val_loss: 1.3557 - val_auc: 0.7470 - val_f1: 0.5066 - lr: 5.0000e-04
# Epoch 51/300
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5143 - auc: 0.8852 - f1: 0.6452 - val_loss: 1.3580 - val_auc: 0.7461 - val_f1: 0.5053 - lr: 5.0000e-04
# Epoch 52/300
# 5/5 [==============================] - 0s 43ms/step - loss: 0.5079 - auc: 0.8866 - f1: 0.6473 - val_loss: 1.3631 - val_auc: 0.7487 - val_f1: 0.5079 - lr: 5.0000e-04
# Epoch 53/300
# 5/5 [==============================] - 0s 47ms/step - loss: 0.5003 - auc: 0.8833 - f1: 0.6502 - val_loss: 1.3723 - val_auc: 0.7465 - val_f1: 0.5066 - lr: 5.0000e-04
# Epoch 54/300
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4938 - auc: 0.8908 - f1: 0.6484 - val_loss: 1.3752 - val_auc: 0.7464 - val_f1: 0.5066 - lr: 5.0000e-04
# Epoch 55/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4926 - auc: 0.8902 - f1: 0.6495 - val_loss: 1.3754 - val_auc: 0.7446 - val_f1: 0.5066 - lr: 5.0000e-04
# Epoch 56/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4899 - auc: 0.8869 - f1: 0.6398 - val_loss: 1.3731 - val_auc: 0.7452 - val_f1: 0.5017 - lr: 5.0000e-04
# Epoch 57/300
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4746 - auc: 0.8916 - f1: 0.6453 - val_loss: 1.3717 - val_auc: 0.7438 - val_f1: 0.5093 - lr: 5.0000e-04
# Epoch 58/300
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4947 - auc: 0.8934 - f1: 0.6630 - val_loss: 1.3762 - val_auc: 0.7515 - val_f1: 0.5066 - lr: 5.0000e-04
# Epoch 59/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4634 - auc: 0.8959 - f1: 0.6486 - val_loss: 1.3820 - val_auc: 0.7453 - val_f1: 0.4919 - lr: 5.0000e-04
# Epoch 60/300
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4639 - auc: 0.8893 - f1: 0.6573 - val_loss: 1.3828 - val_auc: 0.7469 - val_f1: 0.4894 - lr: 5.0000e-04
# Epoch 61/300
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4707 - auc: 0.8905 - f1: 0.6573 - val_loss: 1.3845 - val_auc: 0.7460 - val_f1: 0.4978 - lr: 5.0000e-04
# Epoch 62/300
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4792 - auc: 0.8890 - f1: 0.6482 - val_loss: 1.3911 - val_auc: 0.7446 - val_f1: 0.5053 - lr: 5.0000e-04
# Epoch 63/300
# 5/5 [==============================] - 0s 45ms/step - loss: 0.4800 - auc: 0.8878 - f1: 0.6488 - val_loss: 1.3916 - val_auc: 0.7478 - val_f1: 0.4947 - lr: 5.0000e-04

# %%
#@title 訓練曲線
plt.rcParams.update({'font.size': 8})
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 4))

# Plot training & validation accuracy values
ax1.plot(history.history['loss'])
ax1.plot(history.history['val_loss'])
ax1.set_title('loss')
ax1.set(ylabel='loss', xlabel='Epoch')
ax1.legend(['Train', 'Valid'], loc='lower left')

# Plot training & validation loss values
ax2.plot(history.history['auc'])
ax2.plot(history.history['val_auc'])
ax2.set_title('AUC')
ax2.set(ylabel='AUC', xlabel='Epoch')
ax2.legend(['Train', 'Valid'], loc='upper left')

# Plot training & validation F1-score values
ax3.plot(history.history['f1'])
ax3.plot(history.history['val_f1'])
ax3.set_title('F1-score')
ax3.set(ylabel='F1-score', xlabel='Epoch')
ax3.legend(['Train', 'Valid'], loc='upper left')

plt.show()

# %%
# 儲存模型 save model
h5_file_path = model_dir + "/epoch_end.h5"
model.save(h5_file_path)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 4 評估 Evaluation

# %%
# 讀取模型存檔
h5_file_path = model_dir + "/best_model.h5"
# h5_file_path = model_dir + "/epoch_end.h5"
model = load_model(h5_file_path, compile=False)

# %%
# 預測 驗證集 predict valid_set eagerly
y_true = []
y_pred = []
for x, y in valid_generator:
    y_true.append(y)
    pred = model(x, training=False).numpy()
    y_pred.append(pred)
    print(".", end="")
print("Done!")

y_true = np.concatenate(y_true)
y_pred = np.concatenate(y_pred)
print("y_true shape:", y_true.shape)
print("y_pred shape:", y_pred.shape)
# Out:
# ..Done!
# y_true shape: (76, 5)
# y_pred shape: (76, 5)

# %%
#@title 畫出 ROC曲線
#@markdown https://zh.wikipedia.org/zh-tw/ROC%E6%9B%B2%E7%BA%BF
micro_avg = True  #@param {type:"boolean"}
marco_avg = False  #@param {type:"boolean"}

# 分別算出每一類別的 FPR(假陽率) TPR(真陽率) AUC(roc_curve底下的面積)
N_CLASSES = len(CLASSES)
fpr = dict()
tpr = dict()
lw = 2
roc_auc = dict()
for i in range(N_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

if micro_avg == True:
    # 計算 微觀平均曲線
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

if marco_avg == True:
    # 計算 宏觀平均曲線
    # Compute macro-average ROC curve and ROC area
    
    lw = 2
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(N_CLASSES)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(N_CLASSES):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= N_CLASSES

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    

#### 畫出所有 ROC 曲線 ####
plt.rcParams.update({'font.size': 8})
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

if micro_avg == True:
    plt.plot(fpr["micro"], tpr["micro"],
            label='micro-average ROC curve (area = {0:0.2f})'
                ''.format(roc_auc["micro"]),
            color='deeppink', linestyle=':', linewidth=4)

if marco_avg == True:
    plt.plot(fpr["macro"], tpr["macro"],
            label='macro-average ROC curve (area = {0:0.2f})'
                ''.format(roc_auc["macro"]),
            color='navy', linestyle=':', linewidth=4)

colors = cycle(['cornflowerblue', 'green', 'darkorange', 'red'])
for i, color in zip(range(N_CLASSES), colors):
    ax.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve: {0}\n(area = {1:0.2f})'
             ''.format(CLASSES[i], roc_auc[i]))

ax.plot([0, 1], [0, 1], 'k--', lw=lw)
ax.set(xlim=(0.0, 1.0), ylim=(0.0, 1.0))
ax.axis('equal')
ax.set_xlabel('False Positive Rate (1-specificity)')
ax.set_ylabel('True Positive Rate (sensitivity)')
ax.set_title('Some extension of Receiver operating characteristic to multi-class')
ax.legend(loc="lower right")
plt.show()

# %%
#@title 畫出 混淆矩陣 confusion matrix
class_names = CLASSES
plt.rcParams.update({'font.size': 8})

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
    else:
#         print('Confusion matrix, without normalization')
        pass
#     print(cm)

    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111)
    ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.set_title(title)
#     plt.colorbar()
    tick_marks = np.arange(len(classes))
    ax.axis('equal')
    plt.xticks(tick_marks, classes, rotation='vertical')
    plt.yticks(tick_marks, classes)

    fmt = '.4f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in product(range(cm.shape[0]), range(cm.shape[1])):
        ax.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    ax.set_ylabel('Reference')
    ax.set_xlabel('Predicted')
    plt.tight_layout()

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1))  #
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix and savefig
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.show()
# Plot normalized confusion matrix and savefig
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
plt.show()

# %%
#@title 多分類報告 classification report
report = classification_report(y_true.argmax(axis=1), y_pred.argmax(axis=1), target_names=CLASSES, digits=4)
print(report)
# Out:
#                             precision    recall  f1-score   support
#
#                Phonotrauma     0.6190    0.4643    0.5306        28
# Incomplete glottic closure     0.5238    0.4783    0.5000        23
#                Vocal palsy     0.5625    0.5625    0.5625        16
#                   Neoplasm     0.0000    0.0000    0.0000         7
#                     Normal     0.1429    0.5000    0.2222         2
#
#                   accuracy                         0.4474        76
#                  macro avg     0.3696    0.4010    0.3631        76
#               weighted avg     0.5088    0.4474    0.4711        76

# %%
#@title UAR (Unweighted Average Recall)
uar = recall_score(y_true.argmax(axis=1), y_pred.argmax(axis=1), average='macro')
print("Validation UAR (Unweighted Average Recall) :", uar)
# Out:
# Validation UAR (Unweighted Average Recall) : 0.40100931677018636

# %% [markdown]
# # 5 預測 Prediction
# 對測試資料作答 (public dataset / private dataset)

# %%
[TODO] update later
# Out:
#   Cell In[92], line 1
#     [TODO] update later
#            ^
# SyntaxError: invalid syntax

# %%
# 讀取模型存檔
h5_file_path = model_dir + "/best_model.h5"
model = load_model(h5_file_path, compile=False)
